# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Kosala Rathnayake**

# %% [markdown]
# Data Scientist

# %% [markdown]
# _I'm interested in Data Science because it involves with multiple disciplines and allows me to engage in problem solving using analytical skills_

# %% [markdown]
# ## The follwing code is to plot a line graph

# %%
x = [1, 2, 3, 4]
y = [4, 5, 6, 7]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# + ```The table below has been made as a part of an activity of the Peer Graded Assignment```
# + It has _**4 rows**_ and _**3 columns**_
# + ~~The contents of the last row are striked~~
#
#
# |Header1|Header2|Header3|
# |:-------:|:-------:|:-------:|
# |R2C1|R2C2|R2C3|
# |R3C1|R3C2|R3C3|
# |~~R4C1~~|~~R4C2~~|~~R4C3~~|
